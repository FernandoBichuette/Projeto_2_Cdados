# %% [markdown]
# **Pergunta :** O nivel de escolaridade afeta a chance de uma pessoa perder o emprego?

# %%
import pandas as pd

# %%
dados = pd.read_csv("oecd_USA1.csv")
dados.head()
# Out:
#     LOCATION INDICATOR      SUBJECT   MEASURE FREQUENCY  TIME      Value  \
# 0        USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1981  10.043506
# 1        USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1982  12.582385
# 2        USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1983  15.820516
# 3        USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1984  12.084616
# 4        USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1985  11.455860
# 5        USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1986  11.679307
# 6        USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1987  11.098855
# 7        USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1988   9.461648
# 8        USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1989   8.811384
# 9        USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1990   9.681397
# 10       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1991  12.453908
# 11       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1992  13.508681
# 12       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1993  13.046081
# 13       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1994  12.627853
# 14       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1995  10.007409
# 15       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1996  10.891999
# 16       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1997  10.401124
# 17       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1998   8.516129
# 18       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  1999   7.725040
# 19       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  2000   7.864401
# 20       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  2001   8.143623
# 21       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  2002  10.184658
# 22       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  2003   9.891610
# 23       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  2004  10.472992
# 24       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  2005   9.008231
# 25       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  2006   8.254849
# 26       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  2007   8.470968
# 27       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  2008  10.056567
# 28       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  2009  15.778392
# 29       USA  UNEMPEDU      BUPPSRY  PC_25_64         A  2010  16.820261
# ..       ...       ...          ...       ...       ...   ...        ...
# 84       USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  1989   4.362849
# 85       USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  1990   4.510324
# 86       USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  1991   6.099385
# 87       USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  1992   7.267799
# 88       USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  1993   6.791654
# 89       USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  1994   6.202880
# 90       USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  1995   5.073736
# 91       USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  1996   5.167853
# 92       USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  1997   4.756126
# 93       USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  1998   4.451042
# 94       USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  1999   3.740661
# 95       USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2000   3.584489
# 96       USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2001   3.894848
# 97       USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2002   5.686646
# 98       USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2003   6.061996
# 99       USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2004   5.637989
# 100      USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2005   5.116411
# 101      USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2006   4.564320
# 102      USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2007   4.515807
# 103      USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2008   5.295119
# 104      USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2009   9.786595
# 105      USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2010  11.228783
# 106      USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2011  10.190528
# 107      USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2012   9.093990
# 108      USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2013   8.206664
# 109      USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2014   7.202429
# 110      USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2015   6.048066
# 111      USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2016   5.692104
# 112      USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2017   4.824470
# 113      USA  UNEMPEDU  UPPSRY_NTRY  PC_25_64         A  2018   4.572815
#
#      Flag Codes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# ..          ...
# 84          NaN
# 85          NaN
# 86          NaN
# 87          NaN
# 88          NaN
# 89          NaN
# 90          NaN
# 91          NaN
# 92          NaN
# 93          NaN
# 94          NaN
# 95          NaN
# 96          NaN
# 97          NaN
# 98          NaN
# 99          NaN
# 100         NaN
# 101         NaN
# 102         NaN
# 103         NaN
# 104         NaN
# 105         NaN
# 106         NaN
# 107         NaN
# 108         NaN
# 109         NaN
# 110         NaN
# 111         NaN
# 112         NaN
# 113         NaN
#
# [114 rows x 8 columns]
